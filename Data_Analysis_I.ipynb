# %%
 from matplotlib import pyplot as plt

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
pd.pandas.set_option('display.max_columns',None)
pd.pandas.set_option('display.max_rows',None)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3948b9e4-5f87-426e-8523-31f47a201f73" name="files[]" multiple disabled />
#      <output id="result-3948b9e4-5f87-426e-8523-31f47a201f73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Honda Attribute List_Model.xlsm to Honda Attribute List_Model.xlsm
# ...

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='LookUp',header=1)

# %%
df1.head()
# Out:
#    Unnamed: 0        Business Value  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN      Percentage Total         NaN        1.00         NaN
# 1         NaN  Business Criticality         NaN        0.35         NaN
# 2         NaN             Very High         5.0        1.75         NaN
# 3         NaN                  High         4.0        1.40         NaN
# 4         NaN                Medium         3.0        1.05         NaN
#
#    Usability                   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0        NaN             Percentage Total         NaN        1.00         NaN
# 1        NaN  Number of Application Users         NaN        0.35         NaN
# 2        NaN                          <25         1.0        0.35         NaN
# 3        NaN              25 to 200 users         2.0        0.70         NaN
# 4        NaN             200 to 500 users         3.0        1.05         NaN
#
# ...

# %%
data=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='Attribute List',header=2,index_col=0)

# %%
def rem_spaces(col_name):
    for x in data[col_name]:
        data[col_name]=x.strip()  #The strip() method returns a copy of the string by removing 
                                  #both the leading and the trailing characters (based on the string argument passed).
                                  # The strip() method removes characters from both left and right based on the argument (a string specifying the set of characters to be removed

# %%
rem_spaces('Current Application Usage')

# %%
data.head()
# Out:
#                Quantative Status  Information Missing  \
# Application Id
# 133                    Completed                  NaN
# 577                    Completed                  NaN
# 125                    Completed                  NaN
# AHM 68                 Completed                  NaN
# NaN                    Completed                  NaN
#
#                                    Application Name  \
# Application Id
# 133                                     Absent-Late
# 577                                      Activplant
# 125                                    AEP Delivery
# AHM 68          AHM Legal Matter Application (ALMA)
# NaN                   APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# ...

# %%
#data.rename

# %%
df1.head(80)
# Out:
#     Unnamed: 0                                     Business Value  Unnamed: 2  \
# 0          NaN                                   Percentage Total         NaN
# 1          NaN                               Business Criticality         NaN
# 2          NaN                                          Very High         5.0
# 3          NaN                                               High         4.0
# 4          NaN                                             Medium         3.0
# 5          NaN                                                Low         2.0
# 6          NaN                                           Very Low         1.0
# 7          NaN                                                NaN         NaN
# 8          NaN              Number of Business Proceses Supported         NaN
# 9          NaN                                        More than 5         5.0
# 10         NaN                                             3 to 5         3.0
# ...

# %%
df2=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='Attribute List',header=2,index_col=0)

# %%
df2.head()
# Out:
#                Quantative Status  Information Missing  \
# Application Id
# 133                    Completed                  NaN
# 577                    Completed                  NaN
# 125                    Completed                  NaN
# AHM 68                 Completed                  NaN
# NaN                    Completed                  NaN
#
#                                    Application Name  \
# Application Id
# 133                                     Absent-Late
# 577                                      Activplant
# 125                                    AEP Delivery
# AHM 68          AHM Legal Matter Application (ALMA)
# NaN                   APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# ...

# %%
df2=df2.drop('Information Missing',axis=1)

# %%
dict_age=df1.set_index('Age')['Unnamed: 23'].to_dict()

# %%
dict_age
# Out:
# {'0-2 yrs': 0.7,
#  '10-15 yrs': 2.8,
#  '2-5 yrs': 1.4,
#  '5-10 yrs': 2.0999999999999996,
#  '>15 yrs': 3.5,
#  'Application Age': 0.7,
#  'Application Life Cycle Stage': 0.2,
#  'Current functionality suffices': 0.1,
#  'Deployed-Active': 0.2,
#  'Functional Fitment': 0.1,
#  'Needs major functional upgrade': 0.5,
#  'Needs minor functional upgrade': 0.30000000000000004,
#  'Out of Support': 1.0,
#  'Percentage Total': 0.9999999999999999,
#  'Planned for Sunset': 0.6000000000000001,
#  nan: nan}

# %%
keys = ['0-2 yrs','2-5 yrs','5-10 yrs','10-15 yrs','>15 yrs']
dict_new = {x:dict_age[x] for x in keys}

# %%
dict_new
# Out:
# {'0-2 yrs': 0.7,
#  '10-15 yrs': 2.8,
#  '2-5 yrs': 1.4,
#  '5-10 yrs': 2.0999999999999996,
#  '>15 yrs': 3.5}

# %%
dict_new['5-10 yrs']=2.1

# %%
df2['Application Age']=df2['Application Age'].map(dict_new) #mapping of application age range to its values in lookup

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
b_dict=df1.set_index('Business Value')['Unnamed: 3'].to_dict()

# %%
b_dict
# Out:
# {'1 (Worst) Contained to current uses, planned retirement': 0.2,
#  '1 (Worst) Noncompliant and unacceptable': 0.15,
#  '2 (Below Average)  Noncompliant, but acceptable': 0.3,
#  '2 (Below Average) Tactical, declining role': 0.4,
#  '3 (Average) Partially aligned, acceptable deviations': 0.44999999999999996,
#  '3 (Average) Tactical, stable role': 0.6000000000000001,
#  '3 to 5': 0.8999999999999999,
#  '4 (Better) Aligned, insignificant deviations': 0.6,
#  '4 (Better) Strategic to some functions, future role variable': 0.8,
#  '5 (Best) Fully aligned with current architecture': 0.75,
#  '5 (Best) Strategic and of increasing importance': 1.0,
#  'Architectural Alignment': 0.15,
#  'At least 2': 0.3,
#  'Business Criticality': 0.35,
#  'Future Potential ': 0.2,
#  'High': 1.4,
#  'Low': 0.7,
#  'Medium': 1.0499999999999998,
#  'More than 5': 1.5,
#  'Number of Business Proceses Supported': 0.3,
#  'Percentage Total': 0.9999999999999999,
#  'Very High': 1.75,
#  'Very Low': 0.35,
# ...

# %%
df2.head(10)
# Out:
#                Quantative Status  Information Missing  \
# Application Id
# 133                    Completed                  NaN
# 577                    Completed                  NaN
# 125                    Completed                  NaN
# AHM 68                 Completed                  NaN
# NaN                    Completed                  NaN
# 564                    Completed                  NaN
# 137                    Completed                  NaN
# 139                    Completed                  NaN
# NaN                    Completed                  NaN
# 179                    Completed                  NaN
#
#                                    Application Name  \
# Application Id
# 133                                     Absent-Late
# 577                                      Activplant
# 125                                    AEP Delivery
# AHM 68          AHM Legal Matter Application (ALMA)
# NaN                   APS - Advance Planning System
# ...

# %%
df2['Business Criticality']=df2['Business Criticality'].map(b_dict)

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
keys = ['Future Potential','Architecture Alignment']
for x in keys:
    df2[x]=df2[x].map(b_dict)   #mapping

# %%
df2['Future Potential'].head()
# Out:
# Application Id
# 133       0.6
# 577       1.0
# 125       NaN
# AHM 68    0.6
# NaN       0.6
# Name: Future Potential, dtype: float64

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0        Business Value  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN      Percentage Total         NaN        1.00         NaN
# 1         NaN  Business Criticality         NaN        0.35         NaN
# 2         NaN             Very High         5.0        1.75         NaN
# 3         NaN                  High         4.0        1.40         NaN
# 4         NaN                Medium         3.0        1.05         NaN
#
#    Usability                   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0        NaN             Percentage Total         NaN        1.00         NaN
# 1        NaN  Number of Application Users         NaN        0.35         NaN
# 2        NaN                          <25         1.0        0.35         NaN
# 3        NaN              25 to 200 users         2.0        0.70         NaN
# 4        NaN             200 to 500 users         3.0        1.05         NaN
#
# ...

# %%
u_dict = df1.set_index('Unnamed: 6')['Unnamed: 8'].to_dict()

# %%
u_dict.values()
# Out:
# dict_values([1.0000000000000002, 0.35, 0.35, 0.7, 1.0499999999999998, 1.4, 1.75, nan, 0.2, 1.0, 1.0, 0.8, 0.6000000000000001, 0.4, 0.2, 0.15, 0.5, 0.4, 0.30000000000000004, 0.2, 0.1, 0.2, 1.0, 0.6000000000000001, 0.1])

# %%
for x in list(u_dict):
    if ('Low' in str(x)) or ('Medium' in str(x)) or ('Very' in str(x)) or ('High' in str(x)):
        u_dict.pop(x)

# %%
u_dict
# Out:
# {'200 to 500 users': 1.0499999999999998,
#  '25 to 200 users': 0.7,
#  '500 to 1000 users': 1.4,
#  '<25': 0.35,
#  '>1000 users': 1.75,
#  'Business Users': 0.8,
#  'Current Application Usage': 0.2,
#  'Expected User Growth': 0.1,
#  'External Customer': 1.0,
#  'External Customer and Business Users': 1.0,
#  'IT Team': 0.6000000000000001,
#  'Number of Application Users': 0.35,
#  'Others': 0.2,
#  'Percentage Total': 1.0000000000000002,
#  'Primary Application User': 0.2,
#  'Senior Management': 0.4,
#  'Usability (Intutiveness)': 0.15,
#  nan: nan}

# %%
keys = ['Primary Application User','Number of application users']
for x in keys:
    df2[x]=df2[x].map(u_dict)

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
u_dict
# Out:
# {'200 to 500 users': 1.0499999999999998,
#  '25 to 200 users': 0.7,
#  '500 to 1000 users': 1.4,
#  '<25': 0.35,
#  '>1000 users': 1.75,
#  'Business Users': 0.8,
#  'Current Application Usage': 0.2,
#  'Expected User Growth': 0.1,
#  'External Customer': 1.0,
#  'External Customer and Business Users': 1.0,
#  'IT Team': 0.6000000000000001,
#  'Number of Application Users': 0.35,
#  'Others': 0.2,
#  'Percentage Total': 1.0000000000000002,
#  'Primary Application User': 0.2,
#  'Senior Management': 0.4,
#  'Usability (Intutiveness)': 0.15,
#  nan: nan}

# %%
u_dict.clear()

# %%
u_dict
# Out:
# {}

# %%
u_dict={'Very High':0.75,'High':0.6,'Medium':0.45,'Low':0.3,'Very Low':0.15}

# %%
u_dict
# Out:
# {'High': 0.6, 'Low': 0.3, 'Medium': 0.45, 'Very High': 0.75, 'Very Low': 0.15}

# %%
df2['Usability']=df2['Usability'].map(u_dict)

# %%
u_dict
# Out:
# {'High': 0.6, 'Low': 0.3, 'Medium': 0.45, 'Very High': 0.75, 'Very Low': 0.15}

# %%
u_dict['Very High']=0.5

# %%
#u_dict=u_dict.pop('Very High','High')

# %%
u_dict
# Out:
# {'High': 0.6, 'Low': 0.3, 'Medium': 0.45, 'Very High': 0.5, 'Very Low': 0.15}

# %%
i=0.5
for x in u_dict.keys():
    u_dict[x]=round(i,2)
    i=i-0.1

# %%
u_dict
# Out:
# {'High': 0.4, 'Low': 0.2, 'Medium': 0.3, 'Very High': 0.5, 'Very Low': 0.1}

# %%
df2['Expected user growth']=df2['Expected user growth'].map(u_dict)

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
for x in list(u_dict):
    if ('Very' in str(x)):
        u_dict.pop(x)

# %%
u_dict
# Out:
# {'High': 0.4, 'Low': 0.2, 'Medium': 0.3}

# %%
i=1
for x in u_dict.keys():
    u_dict[x]=round(i,2)
    i=i-0.4

# %%
u_dict
# Out:
# {'High': 1, 'Low': 0.2, 'Medium': 0.6}

# %%
df2['Current Application Usage']=data['Current Application Usage']

# %%
df2['Current Application Usage'].head()
# Out:
# Application Id
# 133       High
# 577       High
# 125       High
# AHM 68    High
# NaN       High
# Name: Current Application Usage, dtype: object

# %%
df2['Current Application Usage']=df2['Current Application Usage'].map(u_dict)

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0        Business Value  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN      Percentage Total         NaN        1.00         NaN
# 1         NaN  Business Criticality         NaN        0.35         NaN
# 2         NaN             Very High         5.0        1.75         NaN
# 3         NaN                  High         4.0        1.40         NaN
# 4         NaN                Medium         3.0        1.05         NaN
#
#    Usability                   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0        NaN             Percentage Total         NaN        1.00         NaN
# 1        NaN  Number of Application Users         NaN        0.35         NaN
# 2        NaN                          <25         1.0        0.35         NaN
# 3        NaN              25 to 200 users         2.0        0.70         NaN
# 4        NaN             200 to 500 users         3.0        1.05         NaN
#
# ...

# %%
dif_dict=df1.set_index('Difficulty to Support')['Unnamed: 13'].to_dict()

# %%
dif_dict
# Out:
# {'18x5': 0.734,
#  '24x7': 1.0,
#  '9x5': 0.466,
#  'Current Support Model': 0.25,
#  'High': 1.2,
#  'Interaction with Business Users': 0.3,
#  'Internally Supported': 0.25,
#  'Jointly with Support Vendor / AMS': 0.75,
#  'Low': 0.6,
#  'Medium': 0.8999999999999999,
#  'Only Supported by Vendor / AMS': 1.25,
#  'Others': 0.2,
#  'Percentage Total': 1.0,
#  'Product Vendor Dependence': 0.25,
#  'Support Coverage': 0.2,
#  'Very High': 1.5,
#  'Very Low': 0.3,
#  nan: nan}

# %%
df2['Current Support Model']=df2['Current Support Model'].map(dif_dict)

# %%
df2['Current Support Model']
# Out:
# Application Id
# 133       0.25
# 577       0.25
# 125       0.25
# AHM 68    0.75
# NaN       0.75
# 564       0.75
# 137       0.25
# 139       0.25
# NaN       0.25
# 179       0.25
# 101       0.75
# 49        1.25
# 110       0.75
# 69        0.25
# 556       1.25
# 70        1.25
# 102       0.75
# 111       0.25
# NaN       0.75
# 114       0.25
# 223       0.25
# 512       0.25
# 73        0.25
# 553       0.75
# 129       0.25
# AHM 69    0.75
# 75        1.25
# 565       1.25
# 76        0.25
# 574       0.75
# 379       1.25
# NaN       0.25
# NaN       1.25
# 37        0.75
# NaN       0.25
# NaN       0.25
# NaN       1.25
# NaN       0.25
# 580       0.25
# NaN       1.25
# 82        0.25
# NaN       0.75
# NaN       0.25
# 65        1.25
# 578       0.75
# NaN       1.25
# 232       0.25
# 117       0.25
# 131       0.75
# 57        1.25
# NaN       0.25
# 575       0.25
# 380       0.25
# NaN       0.25
# 90        1.25
# 89        0.75
# NaN       0.25
# ...

# %%
df2['Support Time Frame']=df2['Support Time Frame'].map(dif_dict)

# %%
df2['Support Time Frame']
# Out:
# Application Id
# 133       1.000
# 577       1.000
# 125       1.000
# AHM 68    1.000
# NaN       0.734
# 564       1.000
# 137       1.000
# 139       1.000
# NaN       0.734
# 179       0.466
# 101       0.200
# 49        0.734
# 110       0.734
# 69        0.466
# 556       0.734
# 70        1.000
# 102       0.200
# 111       1.000
# NaN       1.000
# 114       0.734
# 223       1.000
# 512       0.734
# 73        0.466
# 553       0.466
# 129       1.000
# AHM 69    1.000
# 75        1.000
# 565       0.466
# 76        0.466
# 574       1.000
# 379       1.000
# NaN       0.734
# NaN       1.000
# 37        1.000
# NaN       0.466
# NaN       0.466
# NaN       1.000
# NaN       0.466
# 580       0.466
# NaN       1.000
# 82        0.466
# NaN       0.734
# NaN       0.466
# 65        0.734
# 578       1.000
# NaN       0.200
# 232       0.466
# 117       0.734
# 131       1.000
# 57        0.734
# NaN       1.000
# 575       1.000
# 380       0.466
# NaN       1.000
# ...

# %%
d={'High':1.25,'Medium':0.9175,'Low':0.5825,'NaN':0.25}

# %%
df2['Product Vendor Dependence']=df2['Product Vendor Dependence'].map(d)

# %%
df2['Product Vendor Dependence'].head(10)
# Out:
# Application Id
# 133          NaN
# 577       0.5825
# 125       0.5825
# AHM 68    1.2500
# NaN       1.2500
# 564       0.5825
# 137          NaN
# 139          NaN
# NaN          NaN
# 179          NaN
# Name: Product Vendor Dependence, dtype: float64

# %%
df2['Product Vendor Dependence']=df2['Product Vendor Dependence'].fillna(0.25)

# %%
df2['Product Vendor Dependence']
# Out:
# Application Id
# 133       0.2500
# 577       0.5825
# 125       0.5825
# AHM 68    1.2500
# NaN       1.2500
# 564       0.5825
# 137       0.2500
# 139       0.2500
# NaN       0.2500
# 179       0.2500
# 101       0.9175
# 49        0.9175
# 110       0.5825
# 69        0.5825
# 556       1.2500
# 70        0.9175
# 102       0.9175
# 111       0.2500
# NaN       0.9175
# 114       0.2500
# 223       0.2500
# 512       0.2500
# 73        0.5825
# 553       0.9175
# 129       0.9175
# AHM 69    0.5825
# 75        0.9175
# 565       0.9175
# 76        1.2500
# 574       0.9175
# 379       0.9175
# NaN       0.2500
# NaN       0.5825
# 37        0.9175
# NaN       0.2500
# NaN       0.5825
# NaN       0.5825
# NaN       0.2500
# 580       0.2500
# NaN       0.5825
# 82        0.2500
# NaN       1.2500
# NaN       0.5825
# 65        0.9175
# 578       1.2500
# NaN       1.2500
# 232       0.2500
# 117       0.2500
# 131       0.5825
# 57        0.9175
# NaN       0.5825
# ...

# %%
del d['NaN']

# %%
d
# Out:
# {'High': 1.25, 'Low': 0.5825, 'Medium': 0.9175}

# %%
d['Very High']=1.5
d['Very Low']=0.3

# %%
d
# Out:
# {'High': 1.25,
#  'Low': 0.5825,
#  'Medium': 0.9175,
#  'Very High': 1.5,
#  'Very Low': 0.3}

# %%
d['High']=1.2
d['Medium']=0.9
d['Low']=0.6

# %%
d
# Out:
# {'High': 1.2, 'Low': 0.6, 'Medium': 0.9, 'Very High': 1.5, 'Very Low': 0.3}

# %%
df2['Interaction with Business Users']=df2['Interaction with Business Users'].map(d)

# %%
df2['Interaction with Business Users'].head(10)
# Out:
# Application Id
# 133       0.9
# 577       1.2
# 125       1.2
# AHM 68    1.5
# NaN       1.2
# 564       1.2
# 137       0.9
# 139       1.2
# NaN       0.9
# 179       1.2
# Name: Interaction with Business Users, dtype: float64

# %%
d=df1.set_index('Complexity')['Unnamed: 18'].to_dict()

# %%
d
# Out:
# {'COTS': 0.3,
#  'Construction Type': 0.3,
#  'Current functionality suffices': 0.1,
#  'Developed': 0.8999999999999999,
#  'Functional Complexity': 0.6,
#  'Functional Fitment': 0.1,
#  'High ': 3.0,
#  'Highly Customized COTS': 1.5,
#  'Internal Application': 0.6,
#  'Low': 1.398,
#  'Medium': 2.202,
#  'Moderately Customized COTS': 1.2,
#  'Needs major functional upgrade': 0.5,
#  'Needs minor functional upgrade': 0.30000000000000004,
#  'None': 0.6,
#  'Percentage Total': 0.9999999999999999,
#  nan: nan}

# %%
keys = ['Application Construction Type']
for x in keys:
    df2[x]=df2[x].map(d)
    print(df2[x])
# Out:
# Application Id
# 133       0.9
# 577       0.3
# 125       0.9
# AHM 68    0.9
# NaN       0.3
# 564       0.9
# 137       0.9
# 139       0.9
# NaN       0.9
# 179       1.2
# 101       1.2
# 49        0.9
# 110       0.9
# 69        0.9
# 556       0.9
# 70        0.9
# 102       1.2
# 111       0.9
# NaN       0.9
# 114       0.9
# 223       0.9
# 512       0.9
# 73        0.9
# 553       0.9
# 129       0.9
# AHM 69    1.5
# 75        0.9
# 565       0.3
# 76        0.9
# 574       0.3
# 379       0.9
# NaN       0.9
# NaN       0.9
# 37        0.3
# NaN       0.9
# NaN       0.9
# NaN       0.9
# NaN       0.9
# 580       0.9
# NaN       1.5
# 82        0.9
# NaN       0.3
# NaN       1.2
# 65        0.9
# 578       1.2
# NaN       0.3
# 232       0.9
# 117       0.9
# 131       0.9
# 57        0.9
# NaN       1.2
# 575       1.2
# 380       0.9
# NaN       0.9
# 90        0.9
# 89        0.9
# NaN       0.9
# 163       0.9
# NaN       0.9
# 44        0.9
# NaN       1.5
# ...

# %%
df2['Application Construction Type']=data['Application Construction Type']

# %%
df2['Functional Complexity']
# Out:
# Application Id
# 133          Low
# 577       Medium
# 125        High
# AHM 68     High
# NaN        High
# 564        High
# 137       Medium
# 139       Medium
# NaN       Medium
# 179       Medium
# 101       Medium
# 49        Medium
# 110        High
# 69        Medium
# 556        High
# 70         High
# 102       Medium
# 111        High
# NaN        High
# 114       Medium
# 223       Medium
# 512       Medium
# 73        Medium
# 553       Medium
# 129        High
# AHM 69     High
# 75         High
# 565        High
# 76         High
# 574       Medium
# 379        High
# NaN        High
# NaN        High
# 37        Medium
# NaN       Medium
# NaN       Medium
# NaN          Low
# NaN        High
# 580       Medium
# NaN       Medium
# 82        Medium
# NaN       Medium
# NaN       Medium
# 65        Medium
# 578        High
# NaN        High
# 232       Medium
# 117       Medium
# 131        High
# 57         High
# NaN       Medium
# 575       Medium
# ...

# %%
rem_spaces('Application Construction Type')

# %%
rem_spaces('Functional Complexity')

# %%
rem_spaces('Functional Fitment')

# %%
dict_age
# Out:
# {'0-2 yrs': 0.7,
#  '10-15 yrs': 2.8,
#  '2-5 yrs': 1.4,
#  '5-10 yrs': 2.0999999999999996,
#  '>15 yrs': 3.5,
#  'Application Age': 0.7,
#  'Application Life Cycle Stage': 0.2,
#  'Current functionality suffices': 0.1,
#  'Deployed-Active': 0.2,
#  'Functional Fitment': 0.1,
#  'Needs major functional upgrade': 0.5,
#  'Needs minor functional upgrade': 0.30000000000000004,
#  'Out of Support': 1.0,
#  'Percentage Total': 0.9999999999999999,
#  'Planned for Sunset': 0.6000000000000001,
#  nan: nan}

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df2['Application Life Cycle Stage']=data['Application Life Cycle Stage']

# %%
df2['Application Life Cycle Stage']=df2['Application Life Cycle Stage'].map(dict_age)

# %%
df2['Application Life Cycle Stage']
# Out:
# Application Id
# 133       0.2
# 577       0.2
# 125       0.2
# AHM 68    0.2
# NaN       0.2
# 564       1.0
# 137       0.2
# 139       0.2
# NaN       0.2
# 179       0.2
# 101       0.2
# 49        0.2
# 110       0.2
# 69        0.2
# 556       0.2
# 70        0.2
# 102       0.2
# 111       0.2
# NaN       0.2
# 114       0.2
# 223       0.2
# 512       0.2
# 73        0.2
# 553       0.2
# 129       0.2
# AHM 69    0.2
# 75        0.2
# 565       0.2
# 76        0.2
# 574       0.2
# 379       0.2
# NaN       0.2
# NaN       0.2
# 37        0.2
# NaN       0.2
# NaN       0.2
# NaN       0.6
# NaN       0.2
# 580       0.2
# NaN       0.2
# 82        0.2
# NaN       0.2
# NaN       0.2
# 65        0.2
# 578       0.2
# NaN       0.2
# 232       0.2
# 117       0.2
# 131       0.2
# 57        0.2
# NaN       0.2
# 575       0.2
# 380       0.2
# NaN       0.2
# 90        0.2
# 89        0.2
# NaN       0.6
# 163       0.2
# NaN       0.2
# 44        0.2
# NaN       0.2
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0        Business Value  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0         NaN      Percentage Total         NaN        1.00         NaN
# 1         NaN  Business Criticality         NaN        0.35         NaN
# 2         NaN             Very High         5.0        1.75         NaN
# 3         NaN                  High         4.0        1.40         NaN
# 4         NaN                Medium         3.0        1.05         NaN
#
#    Usability                   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0        NaN             Percentage Total         NaN        1.00         NaN
# 1        NaN  Number of Application Users         NaN        0.35         NaN
# 2        NaN                          <25         1.0        0.35         NaN
# 3        NaN              25 to 200 users         2.0        0.70         NaN
# 4        NaN             200 to 500 users         3.0        1.05         NaN
#
# ...

# %%
dict_age=df1.set_index('Age')['Unnamed: 23'].to_dict()

# %%
dict_age
# Out:
# {'0-2 yrs': 0.7,
#  '10-15 yrs': 2.8,
#  '2-5 yrs': 1.4,
#  '5-10 yrs': 2.0999999999999996,
#  '>15 yrs': 3.5,
#  'Application Age': 0.7,
#  'Application Life Cycle Stage': 0.2,
#  'Current functionality suffices': 0.1,
#  'Deployed-Active': 0.2,
#  'Functional Fitment': 0.1,
#  'Needs major functional upgrade': 0.5,
#  'Needs minor functional upgrade': 0.30000000000000004,
#  'Out of Support': 1.0,
#  'Percentage Total': 0.9999999999999999,
#  'Planned for Sunset': 0.6000000000000001,
#  nan: nan}

# %%
df2['Application Life Cycle Stage'].unique()
# Out:
# array([0.2, 1. , 0.6])

# %%
c=df1.set_index('Operational Risk')['Unnamed: 28'].to_dict()

# %%
c
# Out:
# {'COTS': 0.2,
#  'Construction Type': 0.2,
#  'Developed': 0.6000000000000001,
#  'Functional Complexity': 0.4,
#  'Functional Knowledge Availability': 0.2,
#  'High': 1.0,
#  'High ': 2.0,
#  'Highly Customized COTS': 1.0,
#  'Internal Application': 0.4,
#  'Low': 0.466,
#  'Medium': 0.734,
#  'Moderately Customized COTS': 0.8,
#  'None': 0.4,
#  'Percentage Total': 1.0,
#  'Product Vendor Dependence': 0.2,
#  'Very High': 0.2,
#  'Very Low': 1.0,
#  nan: nan}

# %%
c.clear()

# %%
c={'Very High':0.2,'High':0.4,'Medium':0.6,'Low':0.8,'Very Low':1}

# %%
c
# Out:
# {'High': 0.4, 'Low': 0.8, 'Medium': 0.6, 'Very High': 0.2, 'Very Low': 1}

# %%
df2['Functional Knowledge Availability']=df2['Functional Knowledge Availability'].map(c)

# %%
df2['Functional Knowledge Availability']
# Out:
# Application Id
# 133       0.2
# 577       0.4
# 125       0.4
# AHM 68    0.6
# NaN       0.4
# 564       0.2
# 137       0.8
# 139       0.8
# NaN       0.4
# 179       0.8
# 101       0.4
# 49        0.6
# 110       0.4
# 69        0.4
# 556       0.6
# 70        0.6
# 102       0.4
# 111       0.2
# NaN       0.6
# 114       0.2
# 223       0.2
# 512       0.8
# 73        0.4
# 553       0.4
# 129       0.6
# AHM 69    0.4
# 75        0.6
# 565       0.6
# 76        0.4
# 574       0.6
# 379       0.8
# NaN       0.2
# NaN       0.2
# 37        0.6
# NaN       0.6
# NaN       0.6
# NaN       0.4
# NaN       0.6
# 580       0.2
# NaN       0.2
# 82        0.4
# NaN       0.4
# NaN       0.6
# 65        0.6
# 578       0.2
# NaN       0.4
# 232       0.6
# 117       0.2
# 131       0.6
# 57        0.6
# NaN       0.4
# 575       0.4
# 380       0.4
# NaN       0.2
# 90        0.2
# 89        0.4
# NaN       0.8
# 163       0.2
# NaN       0.6
# 44        0.4
# NaN       0.2
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
c.clear()

# %%
c=df1.set_index('Technical Risk')['Unnamed: 32'].to_dict()

# %%
c
# Out:
# {'Current functionality suffices': 0.25,
#  'Database': nan,
#  'Functional Fitment': 0.25,
#  'Highly Scalable': 0.25,
#  'Moderately Scalable': 0.75,
#  'Needs major functional upgrade': 1.25,
#  'Needs minor functional upgrade': 0.75,
#  'Not Scalable': 1.25,
#  'Operating System': nan,
#  'Percentage Total': 1.0,
#  'Programming Language': nan,
#  'Technical Diversity': 0.5,
#  'Technical Scalability': 0.25,
#  nan: nan}

# %%
df2['Technical Scalability(adding new users/transactions)']=df2['Technical Scalability(adding new users/transactions)'].map(c)

# %%
df2['Technical Scalability(adding new users/transactions)']
# Out:
# Application Id
# 133       0.25
# 577       0.25
# 125       0.25
# AHM 68    0.25
# NaN       0.25
# 564       0.75
# 137       0.25
# 139       0.25
# NaN       0.25
# 179       0.25
# 101       0.25
# 49        0.75
# 110       0.75
# 69        0.25
# 556       1.25
# 70        0.75
# 102       0.25
# 111       0.25
# NaN       0.75
# 114       0.75
# 223       0.25
# 512       0.75
# 73        0.25
# 553       0.25
# 129       0.25
# AHM 69    0.75
# 75        0.75
# 565       0.25
# 76        1.25
# 574       0.75
# 379       1.25
# NaN       1.25
# NaN       0.75
# 37        0.25
# NaN       1.25
# NaN       0.75
# NaN       0.75
# NaN       0.75
# 580       0.75
# NaN       0.25
# 82        0.75
# NaN       0.75
# NaN       0.25
# 65        0.75
# 578       0.25
# NaN       0.25
# 232       0.25
# 117       0.75
# 131       0.25
# 57        1.25
# NaN       0.25
# 575       0.25
# 380       0.25
# NaN       0.25
# 90        0.25
# 89        0.25
# NaN       0.75
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
b_dict
# Out:
# {'1 (Worst) Contained to current uses, planned retirement': 0.2,
#  '1 (Worst) Noncompliant and unacceptable': 0.15,
#  '2 (Below Average)  Noncompliant, but acceptable': 0.3,
#  '2 (Below Average) Tactical, declining role': 0.4,
#  '3 (Average) Partially aligned, acceptable deviations': 0.44999999999999996,
#  '3 (Average) Tactical, stable role': 0.6000000000000001,
#  '3 to 5': 0.8999999999999999,
#  '4 (Better) Aligned, insignificant deviations': 0.6,
#  '4 (Better) Strategic to some functions, future role variable': 0.8,
#  '5 (Best) Fully aligned with current architecture': 0.75,
#  '5 (Best) Strategic and of increasing importance': 1.0,
#  'Architectural Alignment': 0.15,
#  'At least 2': 0.3,
#  'Business Criticality': 0.35,
#  'Future Potential ': 0.2,
#  'High': 1.4,
#  'Low': 0.7,
#  'Medium': 1.0499999999999998,
#  'More than 5': 1.5,
#  'Number of Business Proceses Supported': 0.3,
#  'Percentage Total': 0.9999999999999999,
#  'Very High': 1.75,
#  'Very Low': 0.35,
# ...

# %%
#import os
#path='C:\Users\Rohan Badgujar\Desktop\LTI-APR'
#output_file = os.path.join(path,'modified.csv')
#df2.to_csv(output_file, index=False)

# %%
#df2.to_csv('C:\Users\Rohan Badgujar\Desktop\LTI-APR\modified.csv', index=False)

# %%
df2.to_csv('modified.csv') #convert to csv- modified csv

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='Operating Sys')

# %%
df1.head()
# Out:
#                                     OS Support Cycle  \
# 0              1 - Current Version / Fully Supported
# 1                     2 - EOL posted but > 24 Months
# 2  3 - EOL <= 24 Mos, in Extended Support, or unk...
# 3                                  4 - EOL <= 18 mos
# 4    5 - EOL / EOS / or No Ext Support, or undesired
#
#                                                   AR  Unnamed: 2  \
# 0                           1 - Linux (RHEL, CentOS)         NaN
# 1                                        2 - Windows         NaN
# 2  3 - Mainframe, AIX, COTS, or in extended suppo...         NaN
# 3                                  4 - EOL <= 18 mos         NaN
# 4  5 - EOL/EOS, New MF Development, No Ext. Suppo...         NaN
#
#             OS List  OS Support Cycle.1  AR.1  Rank   EOS Date  \
# 0           AIX 5.3                   5     5   5.0 2012-04-30
# 1           AIX 6.1                   5     5   5.0 2017-04-30
# ...

# %%
df1.set_index('OS List')['Rank'].to_dict()
# Out:
# {'AIX 5.3': 5.0,
#  'AIX 6.1': 5.0,
#  'AIX 6.1.1.0': 5.0,
#  'AIX 7.1, Z/OS 13': 4.0,
#  'Red Hat Linux 6.7': 2.0,
#  'Windows': 4.0,
#  'Windows 2003': 5.0,
#  'Windows 2003 R2': 5.0,
#  'Windows 2008': 4.0,
#  'Windows 2008 R2': 4.0,
#  'Windows 2008 R2 Standard': 4.0,
#  'Windows 2012': 2.5,
#  'Windows 2012 R2': 2.5,
#  'Windows 7 ': 3.0,
#  'Windows 7, AIX': 3.0,
#  'Windows Server 2008 R2': 4.0,
#  'Windows Server 2012 R2': 2.5,
#  'Windows Server 2012 R2 Standard': 2.5,
#  'Z/OS': 3.0,
#  'Z/OS 1.11': 3.0,
#  'Z/OS 1.11, Windows': 3.0,
#  'Z/OS 13, AIX 6.1': 5.0,
#  'Z/OS, Windows 2008 R2': 4.0,
#  nan: 0.0}

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df2['Operating System Revised']=df2['Operating System Revised'].map(df1.set_index('OS List')['Rank'].to_dict())

# %%
df2['Operating System Revised']
# Out:
# Application Id
# 133       3.0
# 577       2.5
# 125       3.0
# AHM 68    4.0
# NaN       2.5
# 564       2.5
# 137       3.0
# 139       3.0
# NaN       3.0
# 179       5.0
# 101       4.0
# 49        5.0
# 110       5.0
# 69        5.0
# 556       5.0
# 70        2.0
# 102       4.0
# 111       3.0
# NaN       5.0
# 114       2.5
# 223       3.0
# 512       5.0
# 73        5.0
# 553       0.0
# 129       NaN
# AHM 69    2.5
# 75        5.0
# 565       2.5
# 76        3.0
# 574       4.0
# 379       4.0
# NaN       3.0
# NaN       5.0
# 37        2.5
# NaN       0.0
# NaN       3.0
# NaN       4.0
# NaN       4.0
# 580       5.0
# NaN       4.0
# 82        3.0
# NaN       2.5
# NaN       4.0
# 65        5.0
# 578       5.0
# NaN       4.0
# 232       5.0
# 117       0.0
# 131       3.0
# 57        5.0
# NaN       2.5
# 575       2.5
# 380       4.0
# NaN       3.0
# 90        4.0
# 89        5.0
# NaN       3.0
# 163       3.0
# NaN       4.0
# 44        5.0
# NaN       5.0
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='ProgLang')

# %%
df1.head()
# Out:
#                       Programming Lang Support Cycle  \
# 0                      1 - Current / Fully Supported
# 1                      2 -EOL known but  > 24 Months
# 2  3 - Ext Support or EOL < 24 Mos, or unknown ve...
# 3                                  4 - EOL <= 18 mos
# 4                     5 - EOL / EOS / or Not Desired
#
#                                                   AR  Unnamed: 2  \
# 0                     1 - Java, Unix Shell Scripting         NaN
# 1                              2 - .Net, VisStudio,          NaN
# 2  3 - COBOL,JCL, Spufi, COTS, One off, Ext. Supp...         NaN
# 3                                  4 - EOL <= 18 mos         NaN
# 4  5 - Not Desired (i.e. Notes, Domino, VBA, VB6,...         NaN
#
#                       PL List  Support  AR.1  Rank    EOL Date  \
# 0              .Net (VS 2010)        3     3   3.0  7/14/20015
# 1  .NET Framework v4.5.2, C#         3     3   3.0  7/14/20015
# ...

# %%
df2['Programming Language Revised']=df2['Programming Language Revised'].map(df1.set_index('PL List')['Rank'].to_dict())

# %%
df2['Programming Language Revised']
# Out:
# Application Id
# 133       3.0
# 577       2.0
# 125       3.0
# AHM 68    5.0
# NaN       5.0
# 564       2.0
# 137       3.0
# 139       3.0
# NaN       3.0
# 179       5.0
# 101       2.5
# 49        5.0
# 110       4.5
# 69        5.0
# 556       3.0
# 70        5.0
# 102       0.0
# 111       3.0
# NaN       4.0
# 114       5.0
# 223       3.0
# 512       NaN
# 73        5.0
# 553       3.0
# 129       3.0
# AHM 69    2.0
# 75        5.0
# 565       2.0
# 76        3.0
# 574       2.0
# 379       5.0
# NaN       4.0
# NaN       3.0
# 37        2.0
# NaN       5.0
# NaN       3.0
# NaN       5.0
# NaN       1.0
# 580       3.0
# NaN       2.0
# 82        3.0
# NaN       3.0
# NaN       3.0
# 65        4.0
# 578       0.0
# NaN       2.0
# 232       5.0
# 117       5.0
# 131       3.0
# 57        5.0
# NaN       3.0
# 575       3.0
# 380       3.0
# NaN       3.0
# 90        5.0
# 89        5.0
# NaN       3.0
# 163       3.0
# NaN       5.0
# 44        5.0
# NaN       2.5
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='Database')

# %%
df1.head()
# Out:
#                                        Support Cycle  \
# 0              1 - Current Version / Fully Supported
# 1                     2 - EOL posted but > 24 Months
# 2  3 - EOL <= 24 Mos, Extended Support, or unknow...
# 3                                  4 - EOL <= 18 mos
# 4    5 - EOL / EOS / or No Ext Support, or undesired
#
#                                                 AR  Unnamed: 2  \
# 0                           1 - DB2, MS SQL, Mongo         NaN
# 1         2 - EOL posted but > 24 Mos, Oracle, IMS         NaN
# 2  3 - COTS, EOL <= 24 mos, or in extended support         NaN
# 3                     4 - one off or EOL <= 18 mos         NaN
# 4       5 - EOL/EOS, No Ext. Support, or undesired         NaN
#
#             DB List  Rank  AR.1  Rank.1   EOL Date  \
# 0       Access 2003     5     5     5.0 2014-04-08
# 1           DB2 8.2     3     3     3.0 2009-04-30
# 2           DB2 9.7     3     3     3.0 2017-09-30
# 3           DB2 V10     3     3     3.0 2017-09-30
# ...

# %%
d = df1.set_index('DB List')['Rank.1'].to_dict()

# %%
d
# Out:
# {'Access 2003': 5.0,
#  'DB2 8.2': 3.0,
#  'DB2 9.7': 3.0,
#  'DB2 V10': 3.0,
#  'DB2, Oracle 11.2': 3.0,
#  'Domino 8.5.3': 5.0,
#  'IMS': 3.0,
#  'MS ACCESS 2003,2007': 5.0,
#  'MS Access': 5.0,
#  'Notes Domino8.5.2': 5.0,
#  'SQL Server 2008': 4.0,
#  'SQL Server 2008 R2 ': 4.0,
#  'SQL Server 2012': 2.5,
#  'SQL Server 2014': 1.0,
#  'SQL Server 2014 (Nucleon)': 1.0,
#  'SQL server 2008R2, DB2 9.1.7': 4.0,
#  'UDB': 3.5}

# %%
df2['Database Revised']=df2['Database Revised'].map(d)

# %%
df2['Database Revised']
# Out:
# Application Id
# 133       3.0
# 577       2.5
# 125       3.0
# AHM 68    4.0
# NaN       1.0
# 564       2.5
# 137       3.0
# 139       3.0
# NaN       3.0
# 179       5.0
# 101       4.0
# 49        1.0
# 110       3.0
# 69        3.0
# 556       4.0
# 70        3.0
# 102       4.0
# 111       3.0
# NaN       3.0
# 114       5.0
# 223       3.0
# 512       4.0
# 73        3.0
# 553       1.0
# 129       3.0
# AHM 69    1.0
# 75        3.0
# 565       2.5
# 76        3.0
# 574       4.0
# 379       5.0
# NaN       3.0
# NaN       3.0
# 37        3.0
# NaN       5.0
# NaN       3.0
# NaN       3.0
# NaN       3.0
# 580       4.0
# NaN       3.0
# 82        3.0
# NaN       2.5
# NaN       4.0
# 65        4.0
# 578       2.5
# NaN       4.0
# 232       3.0
# 117       5.0
# 131       3.0
# 57        5.0
# NaN       1.0
# 575       4.0
# 380       1.0
# NaN       3.0
# 90        1.0
# 89        1.0
# NaN       3.0
# 163       3.0
# NaN       5.0
# 44        3.0
# NaN       3.0
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='MiddleWare')

# %%
df1.head()
# Out:
#                                        Support Cycle  \
# 0                      1 - Current / Fully Supported
# 1                     2 -EOL POSTED but  > 24 Months
# 2  3 - Ext Support or EOL <= 24 Mos, or unknown v...
# 3                                  4 - EOL <= 18 mos
# 4                     5 - EOL / EOS / or Not Desired
#
#                                                   AR  Unnamed: 2  \
# 0                          1 - CICS, MQ Series, GIFT         NaN
# 1  2 - MFT, WebDav(https xfer), SFTP, WebLogic, T...         NaN
# 2  3 - FTP (for internal transfers), ODBC, WCF, W...         NaN
# 3                                  4 - EOL <= 18 mos         NaN
# 4             5 - Not desired or no Extended Support         NaN
#
#                  Middleware List  Support Cycle.1  AR.1  Rank EOL Date  \
# 0        CICS, MQ Series, Vertex                3     3   3.0      NaT
# 1                            NaN                0     0   0.0      NaT
# ...

# %%
df2['Middleware Revised']=df2['Middleware Revised'].map(df1.set_index('Middleware List')['Rank'].to_dict())

# %%
df2['Middleware Revised']
# Out:
# Application Id
# 133       0.0
# 577       2.0
# 125       3.0
# AHM 68    5.0
# NaN       3.0
# 564       2.0
# 137       0.0
# 139       0.0
# NaN       2.0
# 179       0.0
# 101       3.0
# 49        0.0
# 110       5.0
# 69        4.0
# 556       0.0
# 70        4.0
# 102       3.0
# 111       2.5
# NaN       4.0
# 114       5.0
# 223       3.0
# 512       3.0
# 73        4.0
# 553       2.0
# 129       0.0
# AHM 69    0.0
# 75        3.0
# 565       0.0
# 76        0.0
# 574       0.0
# 379       0.0
# NaN       0.0
# NaN       5.0
# 37        5.0
# NaN       0.0
# NaN       0.0
# NaN       4.0
# NaN       2.5
# 580       0.0
# NaN       4.0
# 82        3.0
# NaN       0.0
# NaN       5.0
# 65        3.0
# 578       2.0
# NaN       0.0
# 232       NaN
# 117       0.0
# 131       0.0
# 57        3.0
# NaN       0.0
# 575       0.0
# 380       0.0
# NaN       3.0
# 90        0.0
# 89        5.0
# NaN       0.0
# 163       0.0
# NaN       3.0
# 44        5.0
# NaN       2.5
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='LookUpBV')

# %%
df1.head()
# Out:
#   Unnamed: 0      Bus Fit % Totals  0.8750000000000002  Unnamed: 3  \
# 0        NaN                   NaN                 NaN         NaN
# 1        NaN      Business Fitness                 NaN         NaN
# 2        NaN                   NaN                 NaN         NaN
# 3        NaN  Business Criticality                 NaN       0.025
# 4        NaN             Very High                 5.0       0.125
#
#    Unnamed: 4 Unnamed: 5 Functional Documentation Availability  Unnamed: 7  \
# 0         NaN        NaN    Up to date documentation available         5.0
# 1         NaN        NaN                      Yes but outdated         3.0
# 2         NaN        NaN            No Documentation Available         1.0
# 3         NaN        NaN                                   NaN         NaN
# 4         NaN        NaN                                   NaN         NaN
#
#     HERE  Unnamed: 9
# 0  0.625         NaN
# 1  0.375         NaN
# 2  0.125         NaN
# ...

# %%
df1.set_index('Functional Documentation Availability')['HERE'].to_dict()
# Out:
# {'No Documentation Available': 0.125,
#  'Up to date documentation available': 0.625,
#  'Yes but outdated': 0.375,
#  nan: nan}

# %%
df2['Functional Documentation Availability']=df2['Functional Documentation Availability'].map(df1.set_index('Functional Documentation Availability')['HERE'].to_dict())

# %%
df2['Functional Documentation Availability']
# Out:
# Application Id
# 133       0.625
# 577       0.625
# 125       0.625
# AHM 68    0.625
# NaN       0.625
# 564       0.625
# 137       0.625
# 139       0.625
# NaN       0.125
# 179       0.625
# 101       0.625
# 49        0.375
# 110       0.375
# 69        0.625
# 556       0.375
# 70        0.625
# 102       0.625
# 111       0.625
# NaN       0.625
# 114       0.375
# 223       0.625
# 512       0.375
# 73        0.625
# 553       0.625
# 129       0.375
# AHM 69    0.125
# 75        0.375
# 565       0.625
# 76        0.375
# 574       0.375
# 379       0.625
# NaN       0.375
# NaN       0.375
# 37        0.625
# NaN       0.625
# NaN       0.625
# NaN       0.125
# NaN       0.375
# 580       0.625
# NaN       0.625
# 82        0.625
# NaN       0.625
# NaN       0.625
# 65        0.375
# 578       0.375
# NaN       0.625
# 232       0.625
# 117       0.375
# 131       0.375
# 57        0.625
# NaN       0.625
# 575       0.625
# 380       0.625
# NaN       0.125
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df1=pd.read_excel('Honda Attribute List_Model.xlsm',sheet_name='LookUpBV')

# %%
df1.head()
# Out:
#   Unnamed: 0      Bus Fit % Totals  0.8750000000000002  Unnamed: 3  \
# 0        NaN                   NaN                 NaN         NaN
# 1        NaN      Business Fitness                 NaN         NaN
# 2        NaN                   NaN                 NaN         NaN
# 3        NaN  Business Criticality                 NaN       0.025
# 4        NaN             Very High                 5.0       0.125
#
#    Unnamed: 4 Unnamed: 5 Functional Documentation Availability  Unnamed: 7  \
# 0         NaN        NaN    Up to date documentation available         5.0
# 1         NaN        NaN                      Yes but outdated         3.0
# 2         NaN        NaN            No Documentation Available         1.0
# 3         NaN        NaN                                   NaN         NaN
# 4         NaN        NaN                                   NaN         NaN
#
#     HERE  Unnamed: 9
# 0  0.625         NaN
# 1  0.375         NaN
# 2  0.125         NaN
# ...

# %%
df2['Functional Documentation Availability']=df2['Functional Documentation Availability'].map(df1.set_index('Functional Documentation Availability')['HERE'].to_dict())

# %%
df2['Functional Documentation Availability']=data['Functional Documentation Availability']

# %%
df2['Functional Documentation Availability']
# Out:
# Application Id
# 133       Up to date documentation available
# 577       Up to date documentation available
# 125       Up to date documentation available
# AHM 68    Up to date documentation available
# NaN       Up to date documentation available
# 564       Up to date documentation available
# 137       Up to date documentation available
# 139       Up to date documentation available
# NaN               No Documentation Available
# 179       Up to date documentation available
# 101       Up to date documentation available
# 49                          Yes but outdated
# 110                         Yes but outdated
# 69        Up to date documentation available
# 556                         Yes but outdated
# 70        Up to date documentation available
# 102       Up to date documentation available
# 111       Up to date documentation available
# NaN       Up to date documentation available
# 114                         Yes but outdated
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df2.drop('Information Missing',axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-179-18e288a8e1fc> in <module>()
# ----> 1 df2.drop('Information Missing',axis=1, inplace = True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                                                 About Application  \
# Application Id
# 133             Tracks and maintains data relating to attendan...
# 577             Activplant provides: a highly configurable set...
# 125             Manages parts consolidation & delivery from th...
# AHM 68          Case & Matter Management System. All case rela...
# NaN                                  Capacity and Demand Planning
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# ...

# %%
df2.drop(columns=['About Application','Tower Lead','Application Owner','Honda App SME2'], axis=1,inplace = True)

# %%
df2.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# 133             System of Record           HAFM          Human Resources
# 577             System of Record            MFG         Asset Management
# 125             System of Record            MFG                 Delivery
# AHM 68          System of Record           HAFM       Legal & Compliance
# NaN             System of Record          SCM&A  E-Planning & Purchasing
#
#                                             Core Business Process  \
# ...

# %%
df2.shape
# Out:
# (89, 58)

# %%
df2.to_csv('modified.csv')

# %%
numer_features = [feature for feature in df2.columns if df2[feature].dtype!='O']

# %%
numer_features
# Out:
# ['Business Criticality',
#  'Application Life Cycle Stage',
#  'Future Potential',
#  'Functional Knowledge Availability',
#  'Number of application users',
#  'Technical Scalability(adding new users/transactions)',
#  'Primary Application User',
#  'Usability',
#  'Current Application Usage',
#  'Expected user growth',
#  'Operating System Revised',
#  'Programming Language Revised',
#  'Database Revised',
#  'Middleware Revised',
#  'Architecture Alignment',
#  'Current Support Model',
#  'Product Vendor Dependence',
#  'Interaction with Business Users',
#  'Support Time Frame',
#  'Application Availability Expectation (uptime %)',
#  'Business Fitness',
#  'Operational Risk',
#  'Difficulty to Support',
#  'Age',
#  'OS Rank',
#  'PL Rank',
#  'DB Rank',
#  'Middleware Rank',
#  'Technical Diversity',
#  'Techical Adequacy',
#  'Technical Risk',
#  'Technical Fitness',
#  'Eval Phase']

# %%
len(numer_features)
# Out:
# 33

# %%
categ_features = [feature for feature in df2.columns if df2[feature].dtype=='O']

# %%
categ_features
# Out:
# ['Quantative Status',
#  'Application Name',
#  'Gartner PACE View',
#  'Business Group',
#  'Sub-Business Group',
#  'Core Business Process',
#  'Application Age',
#  'Functional Complexity',
#  'Functional Fitment',
#  'Functional Redundancy',
#  'Redundant Application Name',
#  'Peak frequency',
#  'Impact on Business if application is down',
#  'Application Construction Type',
#  'Application Deployment Type',
#  'Inbound Interfaces',
#  'Outbound Interfaces',
#  'Technical Documentation Availability',
#  'Functional Documentation Availability',
#  'Probability of High Magnitude  Risk',
#  'Avg No of Incidents per Month',
#  'Calculated Quadrant',
#  '.',
#  'TIME Quadrant Notes',
#  'General Comments']

# %%
#check if both lists have any common feature
list(set(numer_features)&set(categ_features))
# Out:
# []

# %%
df2[categ_features].head(80)
# Out:
#                Quantative Status  \
# Application Id
# 133                    Completed
# 577                    Completed
# 125                    Completed
# AHM 68                 Completed
# NaN                    Completed
# 564                    Completed
# 137                    Completed
# 139                    Completed
# NaN                    Completed
# 179                    Completed
# 101                    Completed
# 49                     Completed
# 110                    completed
# 69                     Completed
# 556                    Completed
# 70                     Completed
# 102                    Completed
# 111                    Completed
# NaN                    Completed
# 114                    Completed
# 223                    Completed
# 512                    Completed
# 73                     Completed
# 553                    Completed
# 129                    Completed
# AHM 69                 Completed
# 75                     Completed
# ...

# %%
df2[categ_features].isnull().mean()*100
# Out:
# Quantative Status                             1.123596
# Application Name                              0.000000
# Gartner PACE View                             0.000000
# Business Group                                0.000000
# Sub-Business Group                            0.000000
# Core Business Process                         6.741573
# Application Age                               0.000000
# Functional Complexity                         0.000000
# Functional Fitment                            0.000000
# Functional Redundancy                         0.000000
# Redundant Application Name                   71.910112
# Peak frequency                                0.000000
# Impact on Business if application is down     0.000000
# Application Construction Type                 0.000000
# Application Deployment Type                   0.000000
# Inbound Interfaces                            2.247191
# Outbound Interfaces                           1.123596
# ...

# %%
df2.drop(columns=['Avg No of Incidents per Month','Redundant Application Name'],axis=1,inplace=True)

# %%
def unique_in_columns(column_name):
    l=len(df2[column_name].unique())
    total=len(df2[column_name])
    print('The total number of unique categories in {} column is: {}'.format(column_name,l))
    print('The total length of {} is {}'.format(column_name,total))
    print('The count of individual categorical value is given below: ')
    series = pd.value_counts(df2[column_name])
    print(series)
    print('------------------------------------------------------------------------------------')
    print('Percentage of individual category is:')
    print()
    for x,y in series.items():
        print(x,round(y/total*100,2))

# %%
unique_in_columns('Core Business Process')
# Out:
# The total number of unique categories in Core Business Process column is: 54
# The total length of Core Business Process is 89
# The count of individual categorical value is given below:
# Others                                                                                                                                                                                                                                                            6
# HR tracking                                                                                                                                                                                                                                                       6
# Warranty Analysis                                                                                                                                                                                                                                                 6
# ...

# %%
df2['Core Business Process'].fillna('Others',inplace=True)

# %%
df2['Core Business Process'].isnull().count()
# Out:
# 89

# %%
df = pd.read_csv('modified.csv',header=0,index_col=0)

# %%
df.head()
# Out:
#                Quantative Status                     Application Name  \
# Application Id
# 133                    Completed                          Absent-Late
# 577                    Completed                           Activplant
# 125                    Completed                         AEP Delivery
# AHM 68                 Completed  AHM Legal Matter Application (ALMA)
# NaN                    Completed        APS - Advance Planning System
#
#                Gartner PACE View Business Group       Sub-Business Group  \
# Application Id
# 133             System of Record           HAFM          Human Resources
# 577             System of Record            MFG         Asset Management
# 125             System of Record            MFG                 Delivery
# AHM 68          System of Record           HAFM       Legal & Compliance
# NaN             System of Record          SCM&A  E-Planning & Purchasing
#
#                                             Core Business Process  \
# ...

# %%
categ_features = [feature for feature in df.columns if df[feature].dtype=='O']

# %%
categ_features
# Out:
# ['Quantative Status',
#  'Application Name',
#  'Gartner PACE View',
#  'Business Group',
#  'Sub-Business Group',
#  'Core Business Process',
#  'Application Age',
#  'Functional Complexity',
#  'Functional Fitment',
#  'Functional Redundancy',
#  'Redundant Application Name',
#  'Peak frequency',
#  'Impact on Business if application is down',
#  'Application Construction Type',
#  'Application Deployment Type',
#  'Inbound Interfaces',
#  'Outbound Interfaces',
#  'Technical Documentation Availability',
#  'Functional Documentation Availability',
#  'Probability of High Magnitude  Risk',
#  'Avg No of Incidents per Month',
#  'Calculated Quadrant',
#  '.',
#  'TIME Quadrant Notes',
#  'General Comments']

# %%
def unique_in_columns(column_name):
    l=len(df[column_name].unique())
    total=len(df[column_name])
    print('The total number of unique categories in {} column is: {}'.format(column_name,l))
    print('The total length of {} is {}'.format(column_name,total))
    print('The count of individual categorical value is given below: ')
    series = pd.value_counts(df[column_name])
    print(series)
    print('------------------------------------------------------------------------------------')
    print('Percentage of individual category is:')
    print()
    for x,y in series.items():
        print(x,round(y/total*100,2))

# %%
df[categ_features].isnull().mean()*100
# Out:
# Quantative Status                             1.123596
# Application Name                              0.000000
# Gartner PACE View                             0.000000
# Business Group                                0.000000
# Sub-Business Group                            0.000000
# Core Business Process                         6.741573
# Application Age                               0.000000
# Functional Complexity                         0.000000
# Functional Fitment                            0.000000
# Functional Redundancy                         0.000000
# Redundant Application Name                   71.910112
# Peak frequency                                0.000000
# Impact on Business if application is down     0.000000
# Application Construction Type                 0.000000
# Application Deployment Type                   0.000000
# Inbound Interfaces                            2.247191
# Outbound Interfaces                           1.123596
# ...

# %%
df.drop(columns=['Avg No of Incidents per Month','Redundant Application Name'],axis=1,inplace=True)

# %%
df['Core Business Process'].fillna('Others',inplace=True)

# %%
df.drop('Quantative Status',inplace = True, axis=1)

# %%
df.head()
# Out:
#                                    Application Name Gartner PACE View  \
# Application Id
# 133                                     Absent-Late  System of Record
# 577                                      Activplant  System of Record
# 125                                    AEP Delivery  System of Record
# AHM 68          AHM Legal Matter Application (ALMA)  System of Record
# NaN                   APS - Advance Planning System  System of Record
#
#                Business Group       Sub-Business Group  \
# Application Id
# 133                      HAFM          Human Resources
# 577                       MFG         Asset Management
# 125                       MFG                 Delivery
# AHM 68                   HAFM       Legal & Compliance
# NaN                     SCM&A  E-Planning & Purchasing
#
#                                             Core Business Process  \
# Application Id
# 133                                                   HR tracking
# ...

# %%
unique_in_columns('Outbound Interfaces')
# Out:
# The total number of unique categories in Outbound Interfaces column is: 20
# The total length of Outbound Interfaces is 89
# The count of individual categorical value is given below:
# 0           24
# 1           14
# 2           13
# 10           8
# 4            5
# 3            4
# 15           3
# 7            3
# >50          2
# 6            2
# 10+          2
# 48           1
# 5            1
# 10 TO 20     1
# 100          1
# 60           1
# 33           1
# 28           1
# 98           1
# Name: Outbound Interfaces, dtype: int64
# ------------------------------------------------------------------------------------
# Percentage of individual category is:
#
# 0 26.97
# 1 15.73
# 2 14.61
# 10 8.99
# 4 5.62
# 3 4.49
# 15 3.37
# 7 3.37
# >50 2.25
# 6 2.25
# 10+ 2.25
# 48 1.12
# 5 1.12
# 10 TO 20 1.12
# 100 1.12
# 60 1.12
# 33 1.12
# 28 1.12
# 98 1.12

# %%
df['Calculated Quadrant'].fillna(0,inplace=True)

# %%
unique_in_columns('Calculated Quadrant')
# Out:
# The total number of unique categories in Calculated Quadrant column is: 5
# The total length of Calculated Quadrant is 89
# The count of individual categorical value is given below:
# I    46
# M    26
# E    15
# T     1
# 0     1
# Name: Calculated Quadrant, dtype: int64
# ------------------------------------------------------------------------------------
# Percentage of individual category is:
#
# I 51.69
# M 29.21
# E 16.85
# T 1.12
# 0 1.12

# %%
df['Calculated Quadrant'].isnull().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                                    Application Name Gartner PACE View  \
# Application Id
# 133                                     Absent-Late  System of Record
# 577                                      Activplant  System of Record
# 125                                    AEP Delivery  System of Record
# AHM 68          AHM Legal Matter Application (ALMA)  System of Record
# NaN                   APS - Advance Planning System  System of Record
#
#                Business Group       Sub-Business Group  \
# Application Id
# 133                      HAFM          Human Resources
# 577                       MFG         Asset Management
# 125                       MFG                 Delivery
# AHM 68                   HAFM       Legal & Compliance
# NaN                     SCM&A  E-Planning & Purchasing
#
#                                             Core Business Process  \
# Application Id
# 133                                                   HR tracking
# ...

# %%
df.to_csv('Modified-II.csv')

# %%
df2=pd.read_csv('Modified-II.csv')

# %%
df2.head()
# Out:
#   Application Id                     Application Name Gartner PACE View  \
# 0            133                          Absent-Late  System of Record
# 1            577                           Activplant  System of Record
# 2            125                         AEP Delivery  System of Record
# 3         AHM 68  AHM Legal Matter Application (ALMA)  System of Record
# 4            NaN        APS - Advance Planning System  System of Record
#
#   Business Group       Sub-Business Group  \
# 0           HAFM          Human Resources
# 1            MFG         Asset Management
# 2            MFG                 Delivery
# 3           HAFM       Legal & Compliance
# 4          SCM&A  E-Planning & Purchasing
#
#                                Core Business Process Application Age  \
# 0                                        HR tracking         >15 yrs
# 1                                   Asset maintaince       10-15 yrs
# ...

# %%
df2['Outbound Interfaces'].isnull().sum()
# Out:
# 1
